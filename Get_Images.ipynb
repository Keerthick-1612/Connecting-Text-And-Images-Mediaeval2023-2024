# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/Shareddrives/MediaEval_2023-24/Dataset/RT-Dataset-german/RT-Dataset/rt-train-textImg.txt',sep='\t')

# %%
df.head()
# Out:
#    count          aid                                                url  img  \
# 0      1  2,02205E+13  https://de.rt.com/inland/137811-berliner-bildu...  NaN
# 1      2  2,02205E+13  https://de.rt.com/wirtschaft/137838-deutlicher...  NaN
# 2      3  2,02205E+13  https://de.rt.com/wirtschaft/137843-nach-zinsw...  NaN
# 3      4  2,02205E+13  https://de.rt.com/inland/137820-schiesserei-in...  NaN
# 4      5  2,02205E+13  https://de.rt.com/international/137818-chef-de...  NaN
#
#                         iid                             hashvalue  \
# 0  6274ccc248fbef1aa4192682  UVdfUQoOBkB-XR8FAA5UCAxRQ3JXT19X.jpg
# 1  627510adb480cc068875fdac  UVdfUFhdBBYpUUFXBgtVX1VdRX4DHQYG.jpg
# 2  62752ba3b480cc42f770c095  UVdfUFsPBEEpUUFXBgtRWwtSRXsGSV5Q.jpg
# 3  6274f309b480cc6b5c5b0a2c  UVdfUQ9eVUspUUFXBgtTC1gGRylVGFUG.jpg
# 4  6274dd5b48fbef1b772fcdee  UVdfUQ0JUBB-XR8FAA5UC1pSQC0GHQIA.jpg
#
#                                                title  \
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
images=[]
i=0
base_path="/content/drive/Shareddrives/MediaEval_2023-24/Dataset/RT-Dataset-german/RT-Dataset/images-Train/images-Train"
for imagepath in df["hashvalue"]:
  print(imagepath)
  img = cv2.imread(base_path+"/"+imagepath, cv2.IMREAD_COLOR)
  print(img)
  cv2_imshow(img)
  i+=1
  if i==5:
    break
# Out:
# UVdfUQoOBkB-XR8FAA5UCAxRQ3JXT19X.jpg
# [[[ 65 105  87]
#   [ 62 106  89]
#   [ 56 106  88]
#   ...
#   [193 184 180]
#   [193 185 178]
#   [194 186 179]]
#
#  [[ 60 102  85]
#   [ 60 105  88]
#   [ 55 107  89]
#   ...
#   [192 183 179]
#   [193 185 178]
#   [194 186 179]]
#
#  [[ 54  97  82]
#   [ 55 102  86]
#   [ 53 106  92]
#   ...
#   [190 184 179]
#   [192 183 179]
#   [194 186 179]]
#
#  ...
#
#  [[ 17  21  32]
#   [ 18  22  33]
#   [ 18  22  33]
#   ...
#   [102 113 117]
#   [101 112 116]
#   [101 112 116]]
#
#  [[ 17  21  32]
#   [ 18  22  33]
#   [ 18  22  33]
#   ...
#   [102 113 117]
#   [101 112 116]
#   [101 112 116]]
#
#  [[ 17  21  32]
#   [ 18  22  33]
#   [ 18  22  33]
#   ...
#   [102 113 117]
#   [101 112 116]
#   [101 112 116]]]
# <PIL.Image.Image image mode=RGB size=460x259>
# UVdfUFhdBBYpUUFXBgtVX1VdRX4DHQYG.jpg
# [[[116 176 212]
#   [116 176 212]
#   [116 176 212]
#   ...
#   [124 191 230]
#   [124 191 230]
#   [124 191 230]]
#
#  [[116 176 212]
# ...
